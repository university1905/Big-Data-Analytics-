# %% [markdown]
# # Import Necessary Libraries

# %%
import json
import numpy as np
import pandas as pd

# %% [markdown]
# ### Read and Process Data

# %%
preprocessed_data = []


with open("Sampled_Amazon_Meta.json", 'r') as file:
    for line in file:
        data = json.loads(line)
        
        # Process each row in the dataset
        processed_row = {
            "title": data.get("title"),
            "brand": data.get("brand"),
            "rank": data.get("rank"),
            "category": data.get("category"),
            "asin": data.get("asin"),
            "also_buy": data.get("also_buy")
        }
        preprocessed_data.append(processed_row)

# %%
preprocessed_data
# Out:
# [{'title': "QIBOE Men's Baggy Jeans Denim Sweatpants Loose Pants",
#   'description': ['<b>pant size(Unit:inch)</b><br> W30(tag30) Waist: 30.0 Hip: 41.7 Length: 43.3 Thigh: 26.8 Leg opening: 16.5 <br> W32(tag32) Waist: 32.0 Hip: 43.7 Length: 43.7 Thigh: 27.6 Leg opening: 16.9 <br> W33(tag34) Waist: 33.9 Hip: 45.7 Length: 44.1 Thigh: 28.3 Leg opening: 17.3 <br> W34(tag36) Waist: 35.8 Hip: 47.6 Length: 44.5 Thigh: 29.1 Leg opening: 17.7 <br> W36(tag38) Waist: 37.8 Hip: 49.6 Length: 44.9 Thigh: 29.9 Leg opening: 18.1 <br> W38(tag40) Waist: 40.0 Hip: 51.6 Length: 45.3 Thigh: 30.7 Leg opening: 18.5 <br> W40(tag42) Waist: 42.0 Hip: 53.5 Length: 45.7 Thigh: 31.5 Leg opening: 18.9 <br> W42(tag44) Waist: 44.0 Hip: 55.5 Length: 46.1 Thigh: 32.3 Leg opening: 19.3 <br> W44(tag46) Waist: 46.0 Hip: 57.5 Length: 46.5 Thigh: 33.1 Leg opening: 19.7 <br>'],
#   'brand': 'QIBOE',
#   'rank': '1,506,383 in Clothing, Shoes & Jewelry (',
#   'price': '$38.99',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Men',
#    'Clothing',
#    'Jeans',
#    'Denim',
#    'Zipper closure',
#    'Material: cotton',
#    'Style: hip pop',
#    'Two side slant pockets and two back pockets',
#    'Straight fit long pants'],
#   'asin': '6342509379',
#   'also_buy': ['B077GQQKRV',
#    'B07CBJQTF6',
#    'B07H2Z6S9J',
#    'B06Y26PZ5R',
#    'B012MKMMWO',
#    'B0156SZQ5O',
#    'B0179AUC5Q',
#    'B07C3FNYF5',
#    'B012MKO268',
#    'B07CP532DP',
#    'B01FVRKZ4W',
#    'B0179ATZ9A',
#    'B073P7PHCD',
#    'B076B8J2TX',
#    'B072XTTTK9',
#    'B010V0WTP2',
#    'B071PFP967',
#    'B07H2YZS5K',
#    'B012MKK0J6',
#    'B010V19M8S',
#    'B01M4KD5I7',
#    'B0159XAQ60',
#    'B01E377QRU',
#    'B0034XRCAG',
#    'B07C2M6X6Z']},
#  {'title': "Crazy Women's Voile Crinkle Scarf Shawl",
#   'description': ['Feature <br> -Great quality winter scarf. <br> -A head or neck scarf that can be worn so many ways. A flexible accessory in great fashion colours. Absolutely superb with a coat or jacket and jeans. <br> -The scarf is Soft, Light and with a luxurious feel. <br> -Can be used as every day use or those special occasions <br> -Ideal accessory to jazz up a casual outfit and is a perfect gift. <br> -If you have any problems about our dress,please contact us before placing the order. <br>'],
#   'brand': 'Crazy',
#   'rank': '273,519 in Clothing, Shoes & Jewelry (',
#   'price': '$0.50',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Women',
#    'Accessories',
#    'Scarves & Wraps',
#    'Fashion Scarves',
#    'Material:voile',
#    'Size: 180cm x 95cm',
#    'A scarf that looks great with anything.This scarf would enhance any outfit'],
#   'asin': '6342502315',
#   'also_buy': ['B018YRBB80',
#    'B07FD9HWPM',
#    'B017M55DI4',
#    'B07KX6PPW6',
#    'B017M5BVXA',
#    'B0169ZHJDK',
#    'B00NSF70KM',
#    'B00MQ2R4E0',
#    'B00NV1VFPO',
#    'B01LLOUFRQ',
#    'B01LYDMB6U',
#    'B01CIW8NAG',
#    'B00BIJC8I4',
#    'B00KU1NLGO',
#    'B019ZAYUB0',
#    'B00G9EMVIA']},
#  {'title': 'FQQ Women Sexy Lingerie Lace Dress Sheer Babydoll Underwear G-string Outfit Set',
#   'description': ['Material : Core-spun fabric silk <br> feature: embroider,Free size. <br> function: Breathe freely, body thin leg, hip, open files, prevent to take off the wire. <br> Suitable season :spring, summer, autumn, winter. <br> High transparency and flexibility. <br> This sexy lingerie will make you unique and sexy. Unique style design,Show your perfect body and pretty. How attractive! Wearing it,showing your charm,to be a sexy woman, giving him a surprise and making your life more exotic<br>'],
#   'brand': 'FQQ',
#   'rank': '3,266,227 in Clothing, Shoes & Jewelry (',
#   'price': '$2.80',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Women',
#    'Clothing',
#    'Lingerie, Sleep & Lounge',
#    'Sleep & Lounge',
#    'Nightgowns & Sleepshirts',
#    '100% Polyester',
#    'We use comfortable tissue to make this lovely sexy costume for you',
#    'Material: Lace.Fashion and Sexy Design',
#    'Function: Breathe freely, body thin leg, hip, open files, prevent to take off the wire.',
#    'Adorable caplet will complete your holiday look',
#    'Makes you more attractive and sexy!'],
#   'asin': '6342522545',
#   'also_buy': ['B00VBVXVPI']},
#  {'title': "Crazy Women's Sexy Leather Backless Bodycon Clubwear Mini Dress Nightclub",
#   'description': ['Material : Core-spun fabric silk <br> feature: embroider,Free size. <br> function: Breathe freely, body thin leg, hip, open files, prevent to take off the wire. <br> Suitable season :spring, summer, autumn, winter. <br> High transparency and flexibility. <br> This sexy lingerie will make you unique and sexy. Unique style design,Show your perfect body and pretty. How attractive! Wearing it,showing your charm,to be a sexy woman, giving him a surprise and making your life more exotic<br>'],
#   'brand': 'Crazy',
#   'rank': '641,576 in Clothing, Shoes & Jewelry (',
#   'price': '$8.50',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Women',
#    'Clothing',
#    'Dresses',
#    'Casual',
#    '100% Polyester',
#    'We use comfortable tissue to make this lovely sexy costume for you',
#    'Material: Lace.Fashion and Sexy Design',
#    'Function: Breathe freely, body thin leg, hip, open files, prevent to take off the wire.',
#    'Adorable caplet will complete your holiday look',
#    'Makes you more attractive and sexy! Not include the socks'],
#   'asin': '6342522898',
#   'also_buy': ['B01AHZSZ9A',
#    'B01I809NCO',
#    'B07219C7LQ',
#    'B06ZZBQMT4',
#    'B06XKWCGTT',
#    'B01H43Z5GY',
#    'B01H8BRYXY',
#    'B015W134LS',
#    'B01NBT7VLP',
#    'B0748C68ZX',
#    'B07CMD59N4',
#    'B01JRDL1JE',
#    'B00125SQ44']},
#  {'title': "FQQ Women's Sexy Lingerie Babydoll Dress Sleepwear Bodysuit",
#   'description': ['Material : Core-spun fabric silk <br> feature: embroider,Free size. <br> function: Breathe freely, body thin leg, hip, open files, prevent to take off the wire. <br> Suitable season :spring, summer, autumn, winter. <br> High transparency and flexibility. <br> This sexy lingerie will make you unique and sexy. Unique style design,Show your perfect body and pretty. How attractive! Wearing it,showing your charm,to be a sexy woman, giving him a surprise and making your life more exotic<br>'],
#   'brand': 'FQQ',
#   'rank': '1,761,440 in Clothing, Shoes & Jewelry (',
#   'price': '$4.50',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Women',
#    'Clothing',
#    'Lingerie, Sleep & Lounge',
#    'Sleep & Lounge',
#    'Nightgowns & Sleepshirts',
#    '100% Polyester',
#    'We use comfortable tissue to make this lovely sexy costume for you',
#    'Material: Lace.Fashion and Sexy Design',
#    'Function: Breathe freely, body thin leg, hip, open files, prevent to take off the wire.',
#    'Adorable caplet will complete your holiday look',
#    'Makes you more attractive and sexy! Not include the socks'],
#   'asin': '6342523002',
#   'also_buy': ['B06XY5N95G',
#    'B01LY4VKTL',
#    'B01EKRMG8C',
#    'B004SLKRY6',
#    'B074Z3QGMX',
#    'B01JOVOFRE',
#    'B00UHFS00K',
#    'B0758YYWWB',
#    'B06XKWCGTT',
#    'B016ENOSXQ',
#    'B0723CQH2L']},
#  {'title': "Congs Men's Winter Fleece Lined Military Cargo Pants Casual Outdoor Pants",
#   'description': ["Congs men's pants are all made from cotton materials,which provide you soft,cosy and breathable skin touch. they are in fashionable design with multi cargo pocket,loose style.they are perfect for sports or other leisure outdoor activities.Just choose one to yourself.<br> Fabric:100% cotton<br> Color:wheat/army-green/black<br> Style:casual loose cargo pants<br> Season:autumn/winter<br> Package including:1*men's pants<br> <b>Size Information</b><br> 28 (inch) Waist: 27.56 ; Length: 38.58 ; Thigh: 22.83 <br> 29 (inch) Waist: 29.13 ; Length: 39.37 ; Thigh: 23.62 <br> 30 (inch) Waist: 29.92 ; Length: 40.16 ; Thigh: 23.62 <br> 31 (inch) Waist: 31.50 ; Length: 40.94 ; Thigh: 24.41 <br> 32 (inch) Waist: 33.07 ; Length: 41.73 ; Thigh: 24.80 <br> 33 (inch) Waist: 34.25 ; Length: 42.13 ; Thigh: 25.20 <br> 34 (inch) Waist: 35.43 ; Length: 42.52 ; Thigh: 25.20 <br> 36 (inch) Waist: 36.61 ; Length: 43.31 ; Thigh: 26.77 <br> 38 (inch) Waist: 39.37 ; Length: 44.09 ; Thigh: 27.56 <br>"],
#   'brand': 'Congs',
#   'rank': '224,656 in Clothing, Shoes & Jewelry (',
#   'price': '$35.50',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Men',
#    'Clothing',
#    'Pants',
#    'Casual',
#    '100% Cotton',
#    'Zipper closure',
#    'Material: cotton',
#    'Multi pockets style',
#    'Fleece lined keeps you warm in the cold weather',
#    'Loose and casual styleThe belt is not included',
#    'For detailed size information from PRODUCT DESCRIPTION before ordering and choose fits size'],
#   'asin': '6342503508',
#   'also_buy': ['B077M99VNM',
#    'B07HVRPXYH',
#    'B07CP7DLL5',
#    'B07FDF7NZK',
#    'B0041T42NC',
#    'B07CKXYNY9',
#    'B00XKXI3WG',
#    'B07C8LM5GQ',
#    'B00XKXHX1S',
#    'B07GT4H3SK',
#    'B00V6HPY7A',
#    'B076D5YLC3',
#    'B00S9OXZJW',
#    'B07G612DWD',
#    'B017KE8OG0',
#    'B00MOGZU6M',
#    'B0007ZF4Q8',
#    'B0091CC1OG',
#    'B07JPC4LN6']},
#  {'title': 'Vikings Mens Official TV Series Logo Shield Dark Grey T Shirt',
#   'description': ['Made from a mix of 50% Cotton and 50% Polyester, this mens Vikings T-Shirt is officially licensed and is perfect for fans of the hit TV show. Not only does it provide style and comfort in one neat package, but its also available in a range of sizes, including Small, Medium, Large, XL and XXL. This Vikings Tee is just one of our many TV- and movie-inspired products.'],
#   'brand': 'Vikings',
#   'rank': '1,879,855 in Clothing, Shoes & Jewelry (',
#   'price': '$25.38 - $25.58',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Novelty & More',
#    'Clothing',
#    'Novelty',
#    'Men',
#    'Shirts',
#    'T-Shirts',
#    '50% Cotton and 50% Polyester',
#    'Official, licensed authentic merchandise inspired by the Vikings historical documentary TV series which airs in the History Channel.',
#    'Original design (featuring an aged Red Orange-colored Viking shield emblazoned with the iconic V logo of the Vikings TV series) inspired by the Viking/Norse artwork as shown in the Michael Hirst-written-and-created semi-accurate historical documentary TV series Vikings.',
#    'A comfortable, fitted shirt (boasting of sleeves that hug your arms) made with the highest-quality blend of fabrics (50% Cotton and 50% Polyester) and shirt-printing processes/techniques, such as the interweaving of yarns of mixed colors, which results in flecks of an alternate (i.e., Heathered) color.',
#    'A perfect gift for fans/addicts of Norse/Viking history and of the Michael Hirst-written-and-created semi-accurate blockbuster historical documentary TV series Vikings, which currently airs in the History Channel.',
#    "Machine washable; won't shrink when washed, and its high-quality printing process ensures that the print does not fade over time or after repeated washings."],
#   'asin': '6665562263',
#   'also_buy': ['B00MEX510K']},
#  {'title': 'Honchosfx Mens Retro Creedence Clearwater Revival 1971 T-Shirt Brown',
#   'description': ['Although they found their success in the late 60s and early 70s, Creedence Clearwater Revival remain an important part of the American music culture of today. The band has countless fans the world-over, with many followers captivated by their Southern rock style.<br /><br /> The shirt showcases Creedence Clearwater Revivals Cincinnati Gardens concert from 1971 and is a must-buy for anyone with an eclectic taste in music. The crew neck tee is made from 100% cotton and showcases a bold design across a brown backdrop.<br /><br /> Printed on a soft lightweight cotton tee that has a regular fashionable fit.<br /><br /> For more music-themed products please check out our full range of items.'],
#   'brand': 'Honchosfx',
#   'rank': '598,919 in Clothing, Shoes & Jewelry (',
#   'price': '$21.74',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Novelty & More',
#    'Clothing',
#    'Novelty',
#    'Men',
#    'Shirts',
#    'T-Shirts',
#    '100% Cotton',
#    'Top quality 100% Cotton',
#    'Large retro CCR design',
#    'Soft screenprint',
#    'Exclusive design',
#    'Machine Washable'],
#   'asin': '6665559742',
#   'also_buy': ['B07CM33RK6',
#    'B009A882D0',
#    'B005TS13Y0',
#    'B001RNO30W',
#    'B00318CBS2',
#    'B01LF76SJS',
#    'B00W9DYAIY',
#    'B01HNOIS4A',
#    'B07C5F6YDF',
#    'B012S37HQ6',
#    'B003AIKE6E',
#    'B004GGU9QY',
#    'B01LX9T2O1',
#    'B003AIKE3C',
#    'B007P28FN0',
#    'B07BT98MVN',
#    'B00P2D5U7I',
#    'B001SES07C',
#    'B01M3R75G6',
#    'B00W9DYBDS',
#    'B00KX22PBC',
#    'B07D1TRJ94',
#    'B007KFQ3E0',
#    'B013O1T4NA',
#    'B000000XB8',
#    'B01D10RT22',
#    'B002YAGIOG',
#    'B07BRDZVK2']},
#  {'title': 'Rockatansky Mens Official Mad Max Ford Falcon XB GT Coupe V8 Interceptor Pursuit Special T Shirt Grey',
#   'description': ['Inspired by the post-apocalyptic cult movie Mad Max 2 (1981) starring the famous Aussie actor Mel Gibson, this mens Rockatansky T-Shirt is the perfect tee for the little road warrior within you and boasts a dynamic print which takes inspiration from the movie itself. The design showcases Max Rockatanskys iconic mode of transportation, along with the wordings Rockatansky V8 Interceptor, 1981, super charged and Im just here for the gasoline.<br /><br /> The shirt is made from 100% Cotton, is available in sizes Small to XXXL and is exclusive to Honcho-SFX. Yep, you wont find this anywhere else, so if you love Mad Max, or know someone who does, then this tee is a must-buy.<br /><br /> This Mad Max-themed Teeshirt is just one of many movie tees available from Honcho-SFX.'],
#   'brand': 'Rockatansky',
#   'rank': '995,434 in Clothing, Shoes & Jewelry (',
#   'price': '$21.74',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Novelty & More',
#    'Clothing',
#    'Novelty',
#    'Men',
#    'Shirts',
#    'T-Shirts',
#    '100% Cotton',
#    'Official, licensed authentic Mad Max merchandise exclusive to Honcho-SFX.',
#    'Original design inspired by the V8 Interceptor (or Pursuit Special) car driven by Max Rockatansky (i.e., Mel Gibson) in the movies Mad Max (1979) and Mad Max 2: The Road Warrior (1981). Nearing the end of the first movie, an MFP (i.e., Main Force Patrol) mechanic named Barry remarked She the last of the V8s. She sucks nitro., referring to the car.',
#    'A fitted shirt (boasting of sleeves that hug your arms), designed for comfort and style, made with the highest-quality 100% comfortable Cotton, and featuring a large graphic showing the V8 Interceptor (or Pursuit Special) car, which was based on a 1973 Ford Falcon XB GT Coupe, with some made-for-the-movies modifications.',
#    'A perfect gift for fans/addicts of the late-70s/early-80s post-apocalyptic cult movies Mad Max (1979) and Mad Max 2: The Road Warrior (1981) starring the famous Australian actor Mel Gibson.',
#    "Machine washable; won't shrink when washed, and its high-quality printing process ensures that the print does not fade over time or after repeated washings."],
#   'asin': '6665559939',
#   'also_buy': ['B0778HSPM3',
#    'B0756WNSN1',
#    'B07KWDNJ7M',
#    'B079VXGSP2',
#    'B07CB883LS',
#    'B07CQWP2NF',
#    'B07BNZMNTZ',
#    'B0774BMLF1',
#    'B0767LQ87P',
#    'B07CKRHC35',
#    'B01BHKO34U',
#    'B0759MCXXB',
#    'B01LTHM35C',
#    'B075G5ZWMK',
#    'B01708W3I6']},
#  {'title': 'Honchosfx Mens Retro Creedence Clearwater Revival 1971 T-Shirt Brown',
#   'description': ['Although they found their success in the late 60s and early 70s, Creedence Clearwater Revival remain an important part of the American music culture of today. The band has countless fans the world-over, with many followers captivated by their Southern rock style.<br /><br /> The shirt showcases Creedence Clearwater Revivals Cincinnati Gardens concert from 1971 and is a must-buy for anyone with an eclectic taste in music. The crew neck tee is made from 100% cotton and showcases a bold design across a brown backdrop.<br /><br /> Printed on a soft lightweight cotton tee that has a regular fashionable fit.<br /><br /> For more music-themed products please check out our full range of items.'],
#   'brand': 'Honchosfx',
#   'rank': '598,919 in Clothing, Shoes & Jewelry (',
#   'price': '$21.74',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Novelty & More',
#    'Clothing',
#    'Novelty',
#    'Men',
#    'Shirts',
#    'T-Shirts',
#    '100% Cotton',
#    'Top quality 100% Cotton',
#    'Large retro CCR design',
#    'Soft screenprint',
#    'Exclusive design',
#    'Machine Washable'],
#   'asin': '6665559769',
#   'also_buy': ['B07CM33RK6',
#    'B009A882D0',
#    'B005TS13Y0',
#    'B001RNO30W',
#    'B00318CBS2',
#    'B01LF76SJS',
#    'B00W9DYAIY',
#    'B01HNOIS4A',
#    'B07C5F6YDF',
#    'B012S37HQ6',
#    'B003AIKE6E',
#    'B004GGU9QY',
#    'B01LX9T2O1',
#    'B003AIKE3C',
#    'B007P28FN0',
#    'B07BT98MVN',
#    'B00P2D5U7I',
#    'B001SES07C',
#    'B01M3R75G6',
#    'B00W9DYBDS',
#    'B00KX22PBC',
#    'B07D1TRJ94',
#    'B007KFQ3E0',
#    'B013O1T4NA',
#    'B000000XB8',
#    'B01D10RT22',
#    'B002YAGIOG',
#    'B07BRDZVK2']},
#  {'title': 'Honchosfx Mens Retro Creedence Clearwater Revival 1971 T-Shirt Brown',
#   'description': ['Although they found their success in the late 60s and early 70s, Creedence Clearwater Revival remain an important part of the American music culture of today. The band has countless fans the world-over, with many followers captivated by their Southern rock style.<br /><br /> The shirt showcases Creedence Clearwater Revivals Cincinnati Gardens concert from 1971 and is a must-buy for anyone with an eclectic taste in music. The crew neck tee is made from 100% cotton and showcases a bold design across a brown backdrop.<br /><br /> Printed on a soft lightweight cotton tee that has a regular fashionable fit.<br /><br /> For more music-themed products please check out our full range of items.'],
#   'brand': 'Honchosfx',
#   'rank': '598,919 in Clothing, Shoes & Jewelry (',
#   'price': '$21.74',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Novelty & More',
#    'Clothing',
#    'Novelty',
#    'Men',
#    'Shirts',
#    'T-Shirts',
#    '100% Cotton',
#    'Top quality 100% Cotton',
#    'Large retro CCR design',
#    'Soft screenprint',
#    'Exclusive design',
#    'Machine Washable'],
#   'asin': '6665559734',
#   'also_buy': ['B07CM33RK6',
#    'B009A882D0',
#    'B005TS13Y0',
#    'B001RNO30W',
#    'B00318CBS2',
#    'B01LF76SJS',
#    'B00W9DYAIY',
#    'B01HNOIS4A',
#    'B07C5F6YDF',
#    'B012S37HQ6',
#    'B003AIKE6E',
#    'B004GGU9QY',
#    'B01LX9T2O1',
#    'B003AIKE3C',
#    'B007P28FN0',
#    'B07BT98MVN',
#    'B00P2D5U7I',
#    'B001SES07C',
#    'B01M3R75G6',
#    'B00W9DYBDS',
#    'B00KX22PBC',
#    'B07D1TRJ94',
#    'B007KFQ3E0',
#    'B013O1T4NA',
#    'B000000XB8',
#    'B01D10RT22',
#    'B002YAGIOG',
#    'B07BRDZVK2']},
#  {'title': 'Honchosfx Mens Retro Creedence Clearwater Revival 1971 T-Shirt Brown',
#   'description': ['Although they found their success in the late 60s and early 70s, Creedence Clearwater Revival remain an important part of the American music culture of today. The band has countless fans the world-over, with many followers captivated by their Southern rock style.<br /><br /> The shirt showcases Creedence Clearwater Revivals Cincinnati Gardens concert from 1971 and is a must-buy for anyone with an eclectic taste in music. The crew neck tee is made from 100% cotton and showcases a bold design across a brown backdrop.<br /><br /> Printed on a soft lightweight cotton tee that has a regular fashionable fit.<br /><br /> For more music-themed products please check out our full range of items.'],
#   'brand': 'Honchosfx',
#   'rank': '598,919 in Clothing, Shoes & Jewelry (',
#   'price': '$21.74',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Novelty & More',
#    'Clothing',
#    'Novelty',
#    'Men',
#    'Shirts',
#    'T-Shirts',
#    '100% Cotton',
#    'Top quality 100% Cotton',
#    'Large retro CCR design',
#    'Soft screenprint',
#    'Exclusive design',
#    'Machine Washable'],
#   'asin': '6665559750',
#   'also_buy': ['B07CM33RK6',
#    'B009A882D0',
#    'B005TS13Y0',
#    'B001RNO30W',
#    'B00318CBS2',
#    'B01LF76SJS',
#    'B00W9DYAIY',
#    'B01HNOIS4A',
#    'B07C5F6YDF',
#    'B012S37HQ6',
#    'B003AIKE6E',
#    'B004GGU9QY',
#    'B01LX9T2O1',
#    'B003AIKE3C',
#    'B007P28FN0',
#    'B07BT98MVN',
#    'B00P2D5U7I',
#    'B001SES07C',
#    'B01M3R75G6',
#    'B00W9DYBDS',
#    'B00KX22PBC',
#    'B07D1TRJ94',
#    'B007KFQ3E0',
#    'B013O1T4NA',
#    'B000000XB8',
#    'B01D10RT22',
#    'B002YAGIOG',
#    'B07BRDZVK2']},
#  {'title': 'Honchosfx Mens Retro Creedence Clearwater Revival 1971 T-Shirt Brown',
#   'description': ['Although they found their success in the late 60s and early 70s, Creedence Clearwater Revival remain an important part of the American music culture of today. The band has countless fans the world-over, with many followers captivated by their Southern rock style.<br /><br /> The shirt showcases Creedence Clearwater Revivals Cincinnati Gardens concert from 1971 and is a must-buy for anyone with an eclectic taste in music. The crew neck tee is made from 100% cotton and showcases a bold design across a brown backdrop.<br /><br /> Printed on a soft lightweight cotton tee that has a regular fashionable fit.<br /><br /> For more music-themed products please check out our full range of items.'],
#   'brand': 'Honchosfx',
#   'rank': '598,919 in Clothing, Shoes & Jewelry (',
#   'price': '$21.74',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Novelty & More',
#    'Clothing',
#    'Novelty',
#    'Men',
#    'Shirts',
#    'T-Shirts',
#    '100% Cotton',
#    'Top quality 100% Cotton',
#    'Large retro CCR design',
#    'Soft screenprint',
#    'Exclusive design',
#    'Machine Washable'],
#   'asin': '6665559777',
#   'also_buy': ['B07CM33RK6',
#    'B009A882D0',
#    'B005TS13Y0',
#    'B001RNO30W',
#    'B00318CBS2',
#    'B01LF76SJS',
#    'B00W9DYAIY',
#    'B01HNOIS4A',
#    'B07C5F6YDF',
#    'B012S37HQ6',
#    'B003AIKE6E',
#    'B004GGU9QY',
#    'B01LX9T2O1',
#    'B003AIKE3C',
#    'B007P28FN0',
#    'B07BT98MVN',
#    'B00P2D5U7I',
#    'B001SES07C',
#    'B01M3R75G6',
#    'B00W9DYBDS',
#    'B00KX22PBC',
#    'B07D1TRJ94',
#    'B007KFQ3E0',
#    'B013O1T4NA',
#    'B000000XB8',
#    'B01D10RT22',
#    'B002YAGIOG',
#    'B07BRDZVK2']},
#  {'title': "LJYH Children's Collar Motorcycle Leather Coat Boys Faux Leather Jacket",
#   'description': [],
#   'brand': 'LJYH',
#   'rank': '1,938,710 in Clothing, Shoes & Jewelry (',
#   'price': '$29.99',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Boys',
#    'Clothing',
#    'Jackets & Coats',
#    'Jackets',
#    '100% New Faux Leather Coat',
#    'Fashion New Slim Jacket',
#    'Fashion Style',
#    'Top Quality soft leather',
#    'Easy to wash'],
#   'asin': '7709260446',
#   'also_buy': ['B01AYZJUR4']},
#  {'title': "LJYH Children's Collar Motorcycle Faux Leather Coat Boys Faux Leather Jacket",
#   'description': [],
#   'brand': 'LJYH',
#   'rank': '15,484 in Clothing, Shoes & Jewelry (',
#   'price': '$23.99 - $29.99',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Boys',
#    'Clothing',
#    'Jackets & Coats',
#    'Jackets'],
#   'asin': '7709260373',
#   'also_buy': ['B07C3XB2H1',
#    'B01EFPJ95M',
#    'B075MZPWLY',
#    'B01CP8Y2I0',
#    'B06X96749N',
#    'B077FQP1DS',
#    'B079N979JC',
#    'B01CD2CVTU',
#    'B07CVJC3YT',
#    'B0777F9Q86',
#    'B073MLXYTS',
#    'B075JH6VC3',
#    'B06ZYX6718',
#    'B078WSR1H1',
#    'B074QM8VTG',
#    'B06VVQWTJV',
#    'B06XJCPX69',
#    'B07CNZY5C8',
#    'B075STPY6L',
#    'B013OIAII8',
#    'B07DLRRKY7',
#    'B0158PBFEQ',
#    'B0777HWSFC',
#    'B00RGM5KFK',
#    'B079XMR27F',
#    'B07H14XZV8',
#    'B01L1QTQCO',
#    'B01D4X6ZN0',
#    'B077NF1D7B',
#    'B07JZSYWBN',
#    'B072LN3Y3D',
#    'B072VFPVM8',
#    'B01G1OZQMA',
#    'B07939SZVM',
#    'B07CL5H9RB',
#    'B00MY1DPK0',
#    'B0797MYW9S',
#    'B01KO19LOK',
#    'B01F49BULE',
#    'B07FQ6FRRN',
#    'B07GJNQBHW',
#    'B07D72TBCJ',
#    'B00TFAOIY0',
#    'B075SD9MJF',
#    'B07C4ZS6HD',
#    'B07D6GFMSC',
#    'B07CW54TY2',
#    'B07B3TWQWR',
#    'B01HE3V7UW',
#    'B078VVLQ6J',
#    '0385320434',
#    'B079PTBMXP',
#    'B07DKB669T',
#    'B07CSQZ6SD']},
#  {'title': 'COSPLAZA 80s Heavy Metal Rocker Cosplay Wig Adult Long Straight Black Blonde Spiked Mullet Hair',
#   'description': ['COSPLAZA High Quality Professional Cosplay Costume Wig For Halloween, Christmas,Anime Show, Party, Gathering, Daily Wear, etc.'],
#   'brand': 'COSPLAZA',
#   'rank': '100,326 in Clothing, Shoes & Jewelry (',
#   'price': '$13.99',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Costumes & Accessories',
#    'Men',
#    'Wigs'],
#   'asin': '8181475135',
#   'also_buy': ['B0154RNB54',
#    'B07KGPYSMF',
#    'B07D28CY2Y',
#    'B00LFU25NY',
#    'B00BYS3XAG',
#    'B00BT7XQ7W',
#    'B07CSP6M2C',
#    'B07BKPWCFK',
#    'B07KN9D8Y2',
#    'B077MRN6XC',
#    'B07CQRSXDC',
#    'B01MF9ASUD',
#    'B01MV7MP9F',
#    'B01G3E1XT8',
#    'B074B9SCRC',
#    'B072217Y5P',
#    'B0765P1VRW',
#    'B07KFPWL21',
#    'B01J7YO2GC',
#    'B07CKVHVT3',
#    'B01HLSQUKC',
#    'B079Q6VCP7',
#    'B07BKTH925',
#    'B074ZZMKVR',
#    'B075YRR5L9',
#    'B01FA9UTLA',
#    'B06W2NGKGG',
#    'B074GLRYYX',
#    'B0038292LA',
#    'B07CJPYXV9',
#    'B0799FG2N1',
#    'B009ELWDDS',
#    'B0783RDZQT',
#    'B06XW6HZBS',
#    'B01DNRAHI6',
#    'B014B20XEA',
#    'B00GN3K918',
#    'B07L8TZ7WD',
#    'B07C9CPLJT',
#    'B07D1TRJ94',
#    'B00CES5EKW',
#    'B00J7FWG60',
#    'B06XBZC31V',
#    'B00SIYR5DK',
#    'B00FXA9TKE',
#    'B074NZK8V9',
#    'B01DL9V488',
#    'B07KNBYDLS',
#    'B004NEHRKK',
#    'B071RYG2HF',
#    'B072JX4P31',
#    'B01CADK2MK',
#    'B01M0XV1UL',
#    'B003AIKE0K',
#    'B06XQSRWJZ',
#    'B07BRC7ZY4',
#    'B00C04DQF0',
#    'B075P11G4P',
#    'B01N3D4H2Z',
#    'B009USLJBM',
#    'B00IMB19A4',
#    'B01AA0ETJM',
#    'B07BJBF7B8',
#    'B00Y8DDDO0',
#    'B07M946CPT',
#    'B071NMVFFV',
#    'B079HQGNJZ',
#    'B071K12Y65',
#    'B07K415M8V',
#    'B00P8VODGS',
#    'B06X8WP49V',
#    'B00I5RKNFM',
#    'B071JV3QH6',
#    'B07CHM3VNG',
#    'B01C6OUUMK',
#    'B01EPMT3I8',
#    'B00I5RBJ32',
#    'B074TFBGNT',
#    'B07J67SMPG',
#    'B07BKPDPD3',
#    'B075LBQ6R4',
#    'B0160PAI8M',
#    'B00RD982MO',
#    'B008CUJBQ4',
#    'B073QPJKDJ',
#    'B01LXA1WGH']},
#  {'title': "Alion Women's Sexy Long Sleeve Velvet Slim Button Suit Blazers",
#   'description': ['<br>Marterial: <br><br>we recommend you to double check size measurement in each product description comparing with your clothes.If you haven\'t tried our goods before, we suggest you to pick 1~2 size bigger items.:)<br><br>Package:Other accessories not include<br><br>Material:Polyester<br>Size details:<br>US X-Small=China Medium:Length:24.41"(62cm),Bust:35.43"(90cm),Sleeve Length:22.83"(58cm);<br>US Small=China Large:Length:25.59"(65cm),Bust:37.01"(94cm),Sleeve Length:23.23"(59cm);<br>US Medium=China X-Large:Length:26.77"(68cm),Bust:38.58"(98cm),Sleeve Length:23.62"(60cm);<br>US Large=China 2X-Large:Length:27.95"(71cm),Bust:40.16"(102cm),Sleeve Length:24.02"(61cm);<br>'],
#   'brand': 'Alion',
#   'rank': '226,232 in Clothing, Shoes & Jewelry (',
#   'price': '$21.25 - $75.53',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Women',
#    'Clothing',
#    'Suiting & Blazers',
#    'Blazers',
#    'Polyester',
#    'The size is normally 1~2 size smaller than US size.',
#    'US Small=China Large:Length:25.59"(65cm),Bust:37.01"(94cm),Sleeve Length:23.23"(59cm)',
#    'US Medium=China X-Large:Length:26.77"(68cm),Bust:38.58"(98cm),Sleeve Length:23.62"(60cm)',
#    'US Large=China 2X-Large:Length:27.95"(71cm),Bust:40.16"(102cm),Sleeve Length:24.02"(61cm)'],
#   'asin': '819807905X',
#   'also_buy': ['B07GB9SQSR',
#    'B01NBHX8V8',
#    'B01HTOWZD4',
#    'B07B8DFZ1T',
#    'B074CSMXHY',
#    'B0776KYNM3',
#    'B0722XHLR5',
#    'B0791K4Z6J',
#    'B01JZ49D5O',
#    'B01EVXADEY',
#    'B07C8L5D89',
#    'B00VU2BZLK',
#    'B07CQXRRSS',
#    'B01G7TXF2M']},
#  {'title': "ONTBYB Women's Notch V Neck Long Sleeve Roll-Up Sleeve Zip Up Casual Tunic Shirt Blouse Tops",
#   'description': ['<br>Material:63% Polyester,33.8% Cotton and 3.2% Spandex.<br><br> Fabric: Soft and comfortable.<br><br> Features:Chest flaps,Zipper up,Notch V-neck,Long sleeve with rolled up cuffed,Pure color.<br><br> Occasion: Casual or work.<br><br> Great For Pairing with Any Pants, Jeans, Jeggings,Pencil Skirt.<br><br> Hand wash.No machine wash,No Bleach. Natural air drying is better.<br><br> <br>Size details:<br> Small:Bust:36.22", Botton:43.70", Sleeves:24.02",Length:27.56";<br> Medium:Bust:38.58", Botton:45.28", Sleeves:24.41",Length:28.35";<br> Large:Bust:40.16", Botton:46.85", Sleeves:24.80",Length:29.13";<br> X-Large:Bust:42.13", Botton:48.82", Sleeves:25.20",Length:29.92";<br> XX-Large:Bust:44.09", Botton:50.79", Sleeves:25.59",Length:30.71";<br> 3X-Large:Bust:46.06", Botton:52.76", Sleeves:25.98",Length:31.50".<br>'],
#   'brand': 'ONTBYB',
#   'rank': '1,655,502 in Clothing, Shoes & Jewelry (',
#   'price': '$10.04 - $24.99',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Women',
#    'Clothing',
#    'Tops, Tees & Blouses',
#    'Blouses & Button-Down Shirts',
#    '63% Polyester,33.8% Cotton and 3.2% Spandex.',
#    'This simple blouse desings with Stretchy Comfortable Material to Flattering Your Figure,Hiding Your Belly and Hip,Giving Perfect Body Shape.This is a very nice Fabric and does not easily wrinkle.',
#    'The Classic Henley v-neck pullover blouse top with Adjustable Zipper to make sexy or formal style.',
#    'The Unique & Cute details which is Featuring Chest Flaps with Metallic Hardware and Pockets Decorations are flattering you.',
#    'This nice blouse is Easy to Go with Any Pants, Jeans, Jeggings,Pencil Skirt.',
#    'Perfect for any Occasion: Casual or Work.Suit for this coming fall,winter even spring.'],
#   'asin': '8198157220',
#   'also_buy': ['B07CNRBWJM']},
#  {'title': "Umo Lorenzo Premium Men's Handkerchiefs Collection",
#   'description': ["Inspired by Italy, these 100% cotton Umo Lorenzo boxed and bagged handkerchiefs make great gift items that are loved by customers all over the world. Available in packs of 3, 6, 12 and 13 in a number of classic styles, and great for all sorts of utility and accessory, you're sure to leave an impression with one of these premium Umo Lorenzo handkerchiefs."],
#   'brand': 'Umo Lorenzo',
#   'rank': '281,581 in Clothing, Shoes & Jewelry (',
#   'price': '$11.99',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Men',
#    'Accessories',
#    'Handkerchiefs',
#    'MATERIAL: Handkerchiefs are 100% Pure Cotton',
#    'HANDKERCHIEFS MAKE A GREAT GIFT FOR ANY OCCASION. Buy a set of handkerchief for yourself or as a gift for others. Perfect for gentlemen, grandfathers, fathers, dads, birthdays or anyone who enjoys a classic hankie.',
#    'WONDERFULLY CRAFTED FROM 100% COTTON, which make them naturally soft. Not too thick, not too thin. Cotton is the perfect handkerchief material.',
#    'HANDKERCHIEF SIZE: 16 inches long and 16 inches wide with stitched edges for better quality.',
#    'CARE INSTRUCTION RECOMMENDATIONS: Dry cleaning or hand washing in cold water with a light detergent.'],
#   'asin': '8676838852',
#   'also_buy': ['B00188UDKU']},
#  {'title': 'Leather and Jute Adjustable Believe Inspirational Bracelet',
#   'description': ['Leather and Jute Bracelet with Stainless Steel Centerpiece "Believe" This bracelet is adjustable and will fit most writs'],
#   'brand': 'Gifts by Lulee, LLC',
#   'rank': '904,466 in Clothing, Shoes & Jewelry (',
#   'price': '$9.88',
#   'category': ['Clothing, Shoes & Jewelry', 'Men', 'Jewelry', 'Bracelets'],
#   'asin': '8742240611',
#   'also_buy': ['B018135A52',
#    'B00UVC6YAC',
#    'B00VOXQRAO',
#    'B01DP6GJD2',
#    'B07CPGT7GS']},
#  {'title': 'Blue Simulated Sapphire Zirconia Austrian Crystals Round Set Pendant Necklace 18&quot; Earrings Bracelet 18 ct Gold Plated',
#   'description': ['Charming set, encrusted with shining zirconia. Perfect quality production, beautiful and modern design suitable for ladies of any age who like the luxury. This stunning 18 carat gold plated set with high quality zirconia will make you feel like royalty. It includes a necklace, bracelet and a pair of earrings. Easy to mix and match, this design offers simple yet stunningly delicate feminine elegance. Jewelries are in a nice box . An ideal gift!'],
#   'brand': 'Crystalline Azuria',
#   'rank': '196,449 in Sports & Outdoors (',
#   'price': '$46.00',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Women',
#    'Jewelry',
#    'Jewelry Sets'],
#   'asin': '9543894027',
#   'also_buy': ['B071J2YNR6',
#    'B077YG7CZ7',
#    'B01MRKQYAA',
#    'B01LYT26H6',
#    'B00VHTTN0G',
#    'B072HGDY91',
#    'B019HCYGZQ',
#    'B00N4TIYGQ',
#    'B00VMRB1NU',
#    'B06XRFTKZY',
#    '9543984719',
#    'B017I2J3KA',
#    'B017VH78G8',
#    'B0732Q8QT4',
#    'B00VTDWRGW',
#    'B07BFQF7DK',
#    'B019GS2IK6',
#    'B01LXE51W6',
#    'B074JZJCN3',
#    'B076P4TXB6',
#    'B01MRS4BU1']},
#  {'title': "Tommy Bahama Men's Survivalist",
#   'description': ['Tommy Bahama Men\'s Size Chart \nDon\'t just survive, but thrive in these signature Tommy Bahama&reg; shorts!\nCrafted from a supersoft, washed cotton.\nCargo shorts sport an easy, straight fit and knee length.\nBelt loop waistband.\nElastic waist and interior drawstring offer a comfortable fit.\nZip fly and button closure.\nSlash hand and button-through back pockets.\nButton-flap cargo pockets.\nSignature sailfish logo featured at back pocket.\n100% cotton.\nMachine wash warm, tumble dry low.\nImported.\nMeasurements:\n\n     Waist Measurement: 32 in\n     Outseam: 20 in\n     Inseam: 8 in\n     Front Rise: 12 in\n     Back Rise: 17 in\n     Leg Opening: 24 in\n    \n\nProduct measurements were taken using size MD (32-34" Waist), inseam 8. Please note that measurements may vary by size.'],
#   'brand': '',
#   'rank': '717,299 in Clothing, Shoes & Jewelry (',
#   'price': '',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Men',
#    'Clothing',
#    'Shorts',
#    'Cargo'],
#   'asin': '9789892837',
#   'also_buy': ['B00JGSQQQE',
#    'B07BSV262S',
#    'B06Y292ZRM',
#    'B076J2T2GG',
#    'B076J8GYF5',
#    'B00S50FSH2',
#    'B075V9PT52',
#    'B076J3SLFM',
#    'B071GNZ7T4',
#    'B00XK4XML2',
#    'B0748L5ZP7',
#    'B014DPDHCA',
#    'B0098I81GA',
#    'B07DXVCQPN',
#    'B00OIJT9GU',
#    'B07DYQXKWY',
#    'B00JULWDVO']},
#  {'title': 'Tommy Bahama Mens The Naples Happy Go Cargo 6&quot; Swim Trunks',
#   'description': ['Tommy Bahama Men\'s Size Chart \nPlay it cool and carefree from the poolside to the beach in the Tommy Bahama&reg; Naples Happy-Go-Cargo!\nVolley cut and solid design lend a classic swim look.\nQuick-drying nylon construction will have you comfortable in and out of the water.\nSignature Sailfish embroidery at hem.\nSide seam hand pockets.\nHook-and-loop back pocket.\nHook-and-loop cargo pocket.\nAdjustable drawstring at elastic waist.\nMesh brief lining.\n100% nylon.\nLining: 100% polyester.\nMachine wash and tumble dry.\nImported.\nMeasurements:\n\n     Waist Measurement: 32 in\n     Outseam: 18 in\n     Inseam: 6 in\n     Front Rise: 12 in\n     Back Rise: 17 in\n     Leg Opening: 24 in\n    \n\nProduct measurements were taken using size MD (32-34" Waist). Please note that measurements may vary by size.\nIf you\'re not fully satisfied with your purchase, you are welcome to return any unworn and unwashed items with tags intact and original packaging included.'],
#   'brand': '',
#   'rank': '490,479 in Clothing, Shoes & Jewelry (',
#   'price': '',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Men',
#    'Clothing',
#    'Mesh^Nylon^Polyester',
#    'Imported',
#    "Tommy Bahama Men's Size Chart"],
#   'asin': '9789889399',
#   'also_buy': ['B07BGDDRHV',
#    'B00Z5UJ9CU',
#    'B074PT7XT2',
#    'B073S9M3C2',
#    'B014DPDHCA',
#    'B0785W3BH1',
#    'B01N7JHNMG',
#    'B07CW7J8KG',
#    'B07H9LZ126',
#    'B01MRNES5K',
#    'B01MV12ZLL',
#    'B076J8GYDW',
#    'B01BHZ8A7Q',
#    'B07BSV262S',
#    'B01M1PL782',
#    'B00L5J0OCY',
#    'B01N1K817S',
#    'B00W5QCPAK',
#    'B000N8X7Z4',
#    'B00S50FSH2',
#    'B00U06UIBA',
#    'B071GD1382',
#    'B01M0MW68I']},
#  {'title': 'Tommy Bahama Long Sleeve Easy Breezer Linen Camp Shirt',
#   'description': ['Made of washed linen, this long-sleeve favorite has a relaxed fit and style. \n<br /> \n<br /> \n<br />Note: The size chart shown is the measurements of the actual shirt and NOT your chest. The sizes are approximate. Please email me for specific measurements if you need them. \n<br />'],
#   'brand': '',
#   'rank': '4,079,694 in Clothing, Shoes & Jewelry (',
#   'price': '',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Men',
#    'Clothing',
#    'Shirts',
#    'Casual Button-Down Shirts',
#    '100% Linen',
#    'Front pocket',
#    'Shirttail bottom',
#    'Machine wash'],
#   'asin': '9789880189',
#   'also_buy': ['B00T8OATXM']},
#  {'title': "Tommy Bahama Men's New Pebble Shore V-Neck",
#   'description': ["Tommy Bahama Men's Size Chart \nThe all-season favorite.\nCrafted from a luxurious and supersoft modal blend.\nKnit tee sports a pebble-jacquard texture that lends lightweight luxury to any look.\nV-neck.\nTagless collar.\nShort sleeves.\nHalf-moon yoke.\nStraight hem with split side seams.\n71% modal, 29% polyester.\nMachine wash cold, tumble dry low.\nImported.\nMeasurements:\n\n     Length: 30 in\n    \n\nProduct measurements were taken using size MD. Please note that measurements may vary by size."],
#   'brand': '',
#   'rank': '1,605,984 in Clothing, Shoes & Jewelry (',
#   'price': '$66.90 - $78.00',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Men',
#    'Clothing',
#    'Shirts',
#    'T-Shirts'],
#   'asin': '9789899734',
#   'also_buy': ['B07C28T8NV']},
#  {'title': "Casio Men's Quartz Resin Casual Watch, Color:Black (Model: W59-1V)",
#   'description': ['A tried and true style that always remains in fashion. With its daily alarm, hourly time signal and auto calendar, youll never need to worry about missing an appointment again. Black Casual Classic Watch with a Resin Band.',
#    "With its iconic digital design and host of features, the Classic Watch #59-1V from Casio offers micro-light illumination that's great for casual day or evening wear. This compact and sporty timepiece also includes a 1/100-second stopwatch, hourly time signal, and alarm. Water resistant to 165 feet, and boasting seven years of battery life, this Casio original boasts the precision of quartz movement for optimum reliability."],
#   'brand': 'Casio',
#   'rank': '556,236 in Clothing, Shoes & Jewelry (',
#   'price': '',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Men',
#    'Watches',
#    'Wrist Watches',
#    'Made in USA and Imported',
#    'Quartz movement',
#    'Mineral crystal',
#    'Water resistant to 165 feet (50 M): suitable for swimming and showering',
#    'Micro Light; Daily Alarm'],
#   'asin': '9792252916',
#   'also_buy': ['B000GB1RAU',
#    'B000GAWSDG',
#    'B000VODU5M',
#    'B0721BB2ZX',
#    'B01N7XKNSX',
#    'B000LAKYW8',
#    'B000GAYQJ0',
#    'B001B03MXU',
#    'B000GB1R7S',
#    'B000J34HN4',
#    'B001AWZDA4',
#    'B0053HDR78',
#    'B000GB1RCI',
#    'B002J4UBJ0',
#    'B0721BB2ZW',
#    'B005JVP2NU',
#    'B01MZF6LL2',
#    'B07D926L1B',
#    'B000AQVRYC',
#    'B00006I551',
#    'B002J4UBJA',
#    'B07BFHBHXC',
#    'B00MDIUIFE',
#    'B078V3LDLJ',
#    'B00134L97K',
#    'B000GAWSFO',
#    'B000GAYQKY',
#    'B07C9F8XLL',
#    'B0053HBJBE',
#    'B079KDNTZP',
#    'B00F0NCEDI',
#    'B007EBUBCK',
#    'B00J6IITPK',
#    'B00067KRVO',
#    'B07FJXCYBB',
#    'B01MY8CBXB',
#    'B006CHML4I',
#    'B000GB0G2A',
#    'B000GAWS7W',
#    'B003BJFQW4',
#    'B005FEY47Q',
#    'B007421JGG',
#    'B000AQVRWO',
#    'B000JNKABW',
#    'B00001WRSJ',
#    'B007RWZHXO',
#    'B00X08P2TI',
#    'B07734SKFC',
#    'B01BCZRT1O',
#    '1941234518',
#    'B074848WC7',
#    'B009RA6C1K',
#    'B00009LI4K',
#    'B000HZT48M',
#    'B019FELCFI']},
#  {'title': 'Tommy Bahama Survivor Elastic Waist Shorts',
#   'description': ["Do you have what it takes to survive in paradise? These shorts sure do! Whether you're exploring a new-found beach or scraping barnacles from your sailboat, you'll love the comfortable elastic waistband and ample pockets for storing your daily necessities."],
#   'brand': '',
#   'rank': '355,964 in Clothing, Shoes & Jewelry (',
#   'price': '',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Men',
#    'Clothing',
#    'Shorts',
#    'Cargo',
#    '100% cotton',
#    'Machine wash warm; tumble dry on low setting. Can also be dry cleaned',
#    'Inseam: 8"',
#    'Drawstring waist'],
#   'asin': '9830031918',
#   'also_buy': ['B01MV12ZLL',
#    'B07BSV262S',
#    'B01C6FC5BS',
#    'B076JC26DQ',
#    'B07CJZ5DLL',
#    'B00XK4XML2',
#    'B07DYQXKWY',
#    'B017E1E1XE',
#    'B00JULWOFE',
#    'B01CZ0LJCU']},
#  {'title': 'Stretch Gloves Sleeves Arm Cover Veil Hijab Hejab Islamic Islam Abaya Muslim',
#   'description': ['',
#    'ITEM DESCRIPTION : soft and comfortable long stretchable arm sleeves,enjoy your modest and proper hijab with such soft materials which will make you very comfortable in both summer and -winter.available in many colors to match your hijab or your cloths',
#    '(black-dark blue-brown-white-grey)',
#    'Condition : 100% NEW',
#    'Quantity : TWO pcs',
#    'Color : chose your color',
#    'Weight (Approx.) : 10-15 gm = ( 0.35 - 0.52 Oz ) each one',
#    'Material : 100 % high quality polyester',
#    'Size : LENGTH: 30-34 cm = 12"- 13.6" INCH without stretch -40-42 cm = 16-17 inch after stretch -SIZE: ONE SIZE FITS ALL'],
#   'brand': 'bonballoon',
#   'rank': '2,176,681 in Clothing, Shoes & Jewelry (',
#   'price': '',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Novelty & More',
#    'Clothing',
#    'Novelty',
#    'Women',
#    'Accessories',
#    'Gloves & Mittens',
#    'Gloves',
#    'Delivery time: About 3 weeks - Stretch Gloves Sleeves Arm Cover Veil Hijab Hejab Islamic Islam Abaya Muslim',
#    'Size:LENGTH:30 - 34cm = 12"-13.6" - without stretch:40 -4 2cm =16-17 after stretch',
#    'ONE SIZE FITS ALL - Weight:10 - 15 gm = ( 0.35 - 0.52 Oz ) - Material:high quality polyester',
#    'Quantity:TWO pcs - Color:chose your color',
#    'Condition:NEW WITH HIGH QUALITY'],
#   'asin': '9955164174',
#   'also_buy': ['B00MFJ0IJW',
#    'B013JZ9YFY',
#    'B017SFEMKS',
#    'B073NY6JQL',
#    'B01M7U1EK1',
#    'B06Y69K8Q2',
#    'B06ZZVGS11',
#    'B01M70OTFQ',
#    'B01IXUIMS0',
#    'B005IC4V8C',
#    '1461104777',
#    '0860374637']},
#  {'title': 'Prouds of America Independence Day 4th of July T-Shirt for Men',
#   'description': ['Great shirt to wear as part of your 4th of July clothing ensemble to celebrations and fireworks display. Celebrating the Independence of America with Hamburgers and Hots Dog on the BBQ with family is a tradition in the USA'],
#   'brand': 'ProAms',
#   'rank': [],
#   'price': '$33.91',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Men',
#    'Clothing',
#    'Shirts',
#    'T-Shirts',
#    'Imported',
#    'Machine wash cold with like colors, dry low heat',
#    'There Are More Colors To Choose From',
#    'Normally 7-15 Business Days For Delivery By USPS.',
#    'Digital Direct Printing,eco-friendly Ink.100% Comfortable Cotton,Machine Washable.',
#    'Prouds of America'],
#   'asin': 'B0000002A8',
#   'also_buy': ['B000000EYP']},
#  {'title': 'Army Men 3D',
#   'description': ['The little plastic army men you played with as a child are toys no longer! They are now living beings bent on destruction. Of course, you get to play an integral role in the conflict as Sarge, a sergeant (you were expecting another rank?) in the Green Army. While your objectives vary with each mission, the goal is to defeat the evil Tan Army using a little strategy and a lot of firepower. Since you\'ll also have to confront members of the Blue and Gray armies, you are essentially outnumbered three to one! Roll, duck, kneel, and cycle through your available weapons as you try to complete the objectives detailed at the beginning of each level. Missions range from search-and-destroy to rescue or reconnaissance operations, and you\'ll even drive one of four vehicles during the battles. Units include versions of six classic toys: Rifle Man, Grenadier, Bazooka Man, Mortar Man, Flamethrower, and Minesweeper. Play involves controlling Sarge from a third-person viewpoint, although switching to the "Combat Cam" allows players to get a closer view of their surroundings with a perspective just behind the character\'s shoulder. The game also offers three modes of play including a Boot Camp to practice the controls, a single-player Campaign against the Tan Army, and a Two-Player game against a friend or foe. The Two-Player game is a variant on Capture the Flag in that you must sneak into your opponent\'s base to retrieve his or her flag. Once the flag is safely in your base, you\'ll win the game. Other notable features include three levels of difficulty, two controller configurations and support for the Dual Shock Analog Controller. A memory card with one block of free data is also required in order to save progress.',
#    "Army Men 3D is a three-dimensional war game wherein you act as a commando-like soldier in a world gone completely Saving Private Ryan, plastic, and lilliputian. It's a world with some narrative behind it, so a history lesson is necessary before we proceed. After shifting solely to software development awhile back, 3DO introduced a lighthearted real-time strategy game to the PC revolving around little plastic army men named...  Army Men, and since it sold well, the company developed the concept into a franchise. To date, another PC strategy game as well as this one (a third-person shooter) has been released, while a third-person N64 adventure game (Army Men: Sarge's Heroes) and a PlayStation helicopter game (Army Men: Air Attack) have been announced. <P>Army Men 3D places you as Sarge, a lone soldier whose missions involve rescuing captured troops and returning them across a minefield, taking on an enemy fortress unaided, retrieving sensitive documents from spies in the field, sabotaging bridges and radar dishes, and the like. You're in the Green army, which is at war with the Tan, and you've got an arsenal ranging from machine guns and bazookas to flame throwers and grenades - all of which you use to fight the good fight. There are even jeeps and tanks for you to drive around and over people. <P>Sound like a good concept? It is. There are a few really neat things about the game. Sneaking around as a commando and ducking behind rocks to avoid enemy fire can be very fun, and a number of the missions present some enjoyable challenges. Likewise, the mechanics behind the grenades and mortars is great. When you press the fire button, a square-shaped target moves away from you to the maximum distance the mortar or grenade can be shot or thrown and continues back and forth until you let go of the button to launch the shot. However, there are a number of factors that pile up and drag Army Men 3D way down. <P>The graphics are the main offender here; they are muddy beyond even those in Sega's House of the Dead on the Saturn. This is less an aesthetic complaint than a practical one, because you'll often not be able to distinguish an enemy soldier from a cactus or brush, and the terrain often has inexplicable sticky spots, both of which can get you shot. The later levels in the bayou look better than the desert stages (where pop-up runs rampant) and save the game from getting an even lower graphical score. There are some control and gameplay problems at work, as well. The control set-up feels somewhat incomplete because of the lack of a gun sight in the look mode and no strafe button at all. The gun sight is substituted by a computer-controlled intelligent aiming function that hones in on foes in the area toward which you've pointed your muzzle, but sometimes it gets confused when enemies are clustered together. If an enemy is farther away and not shooting at you, you might choose to ignore him for a moment, but the aiming function won't always let you. The prerequisite strafe button is replaced by the ability to roll left and right, which is probably a bit more realistic, but the need for more precise control becomes apparent the first time you get caught in a crossfire. <P>As it might sound, it's very easy to get killed in Army Men 3D. You can be right near the end of a level, walk around a corner, and get eaten right up by a machine gunner. It actually happens a lot, so it makes you start wishing for less powerful bullets or mid-level save spots. The way it stands, there are a lot of instances when you'll quit the game out of frustration, only to continue later out of stubbornness - meaning that the game is often maddening, but at least it does provide compelling enough reasons to continue.  <P>Other items worth mentioning: The music and sound aren't very strong, and the game is a little bit on the short side. The game camera is near perfect in the single-player mode because it sticks right behind your back, but since it's trimmed b ...
#   'brand': 'Panasonic 3DO (Games)',
#   'rank': ['>#18,319 in Video Games (See Top 100 in Video Games)',
# ...
#    'B07GZ1LC6P',
#    'B002Q00O3A',
#    'B077YYTPTS',
#    'B00U06KSSI',
#    'B016TUDBEG',
#    'B014V62CXQ',
#    'B00E5WVH0Q',
#    'B01ESXYERO',
#    'B07CQPJGX7',
#    'B002Q04LHA',
#    'B011GP9MIS',
#    'B01JK759R2',
#    'B06XZ4S379',
#    'B07CJK4NGN',
#    'B075K89QGN',
#    'B07HXM5CZ1',
#    'B00L3YCRSK',
#    'B01JK759TU',
#    'B07CKC2F6T',
#    'B00GTT9NEA',
#    'B010T6TS4I',
#    'B01M16PNSD',
#    'B00L3YCRN0',
#    'B00AAZVITC',
#    'B01JK759SG',
#    'B004DMYNBI',
#    'B004DNWNEG',
#    'B013WMWV36',
#    'B014E9N568',
#    'B00NOU4KVS',
#    'B00I3S5K6U',
#    'B005ZY14JW',
#    'B076FB8B19',
#    'B07C9N577B',
#    'B009Q6ND0S',
#    'B075DQ86FL',
#    'B07C9H78QT',
#    'B0002V32NE',
#    'B07C66P9D2',
#    'B000B2M2XK',
#    'B008VRXF74',
#    'B0083QNM3U',
#    'B004YJQ02K',
#    'B00LI3MRAY',
#    '1591845548',
#    'B07H7DWFHN',
#    'B07HJFLWZN',
#    'B01AHGEM8M',
#    'B0002V31Z8',
#    'B0761VW13Z',
#    'B007IEA12S',
#    '1501175513',
#    'B00SM0O2QS',
#    'B07C32YJLR',
#    'B003G6YFWY',
#    'B0119V9TSM',
#    'B009YQ5Q3C',
#    'B002PZVCVE',
#    'B00FA3QM5Y',
#    'B079HJFY8B',
#    'B00JEYXZ5U',
#    'B007BOEJAA',
#    'B0000BVG6F',
#    '0865653518',
#    'B074M9KVDL',
#    'B07L76JPPM',
#    'B00IJ35A82']},
#  {'title': "Hanes Women's Control Top Reinforced Toe Silk Reflections Panty Hose",
#   'description': ['Silk reflections silky sheer reinforced toe control top',
#    'Silk Reflections Silky Sheer Reinforced Toe Control Top'],
#   'brand': '',
#   'rank': '1,969 in Clothing, Shoes & Jewelry (',
#   'price': '$3.70 - $25.10',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Women',
#    'Clothing',
#    'Socks & Hosiery',
#    'Sheers'],
#   'asin': 'B0000891KM',
#   'also_buy': ['B004DNWNDC',
#    'B009YQ5Q3C',
#    'B009Q6ND0S',
#    'B004DNWN3C',
#    'B00NOU42G6',
#    'B009YQ5Q4Q',
#    'B00MA702HW',
#    'B004DNWMN8',
#    'B0002V31Z8',
#    'B00ZGQFHGA',
#    'B009ZT52J6',
#    'B011GP94EK',
#    'B011GPA1V0',
#    'B0119V9TSM',
#    'B00ZGQEYA0',
#    'B0724ZL1PT',
#    'B00NOU4KVS',
#    'B01MU2ZHRH',
#    'B00NOU4E6O',
#    'B00LI3MRAY',
#    'B00MA7027C',
#    'B01N22S356',
#    'B01N3Q3UOG',
#    'B00NOU3ZVE',
#    'B07BS37NNF',
#    'B0002V32NE',
#    'B00LVNUH80',
#    'B00NOU4I4M',
#    'B078R4RXV6',
#    'B01JZ98JA4',
#    'B009YQ5QGO',
#    'B00LVNUH5I',
#    'B0765C5C6F',
#    'B004DNWNF0',
#    'B076D4LQ97',
#    'B07BVYVDYD',
#    'B07BL2M7ZN',
#    'B07BJBS4PB',
#    'B07BZHG1KN',
#    'B01E580XX6',
#    'B075DQ86FL',
#    'B00VU78P5E',
#    'B00C28SFAU',
#    'B07CQC7B4S',
#    'B078X21SM4',
#    'B01LXAY36A',
#    'B07H2RY8SQ',
#    'B00U2VQZDS',
#    'B00WHXQIJA',
#    'B07CKQS1BL',
#    'B01KPPOMUS',
#    'B01I21CP7O',
#    'B00BUI5QWS',
#    'B07F22VFWT',
#    '1984825488']},
#  {'title': "Converse Kids' Chuck Taylor All Star Canvas High Top Sneaker",
#   'description': ['The iconic, timeless chuck taylor all star sneaker. Perfect in its simplicity since 1917. Lightweight, breathable canvas construction. Vulcanized rubber sole delivers durable traction. AND no one can ignore the unmistakable ankle patch. Versatile, fashionable, and they keep looking better every time you wear them.'],
#   'brand': '',
#   'rank': '8,927 in Clothing, Shoes & Jewelry (',
#   'price': '',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Men',
#    'Shoes',
#    'Fashion Sneakers'],
#   'asin': 'B000089V7W',
#   'also_buy': ['B07621XZWC',
#    'B07K598JQ1',
#    'B078J5W5Z2',
#    'B00EUOVEPM',
#    'B0797L7D8W',
#    'B07DQ2BSRB',
#    'B079PF6Q8B',
#    'B079C4YJ9R',
#    'B0762NC5ZJ',
#    'B079XMR27F',
#    'B07CQ7X81L',
#    'B078J3N6HG',
#    'B0743XVD87',
#    'B07B5FVT5K',
#    'B07HVFM4CG',
#    'B07C8V9T7T',
#    'B079CX34K3',
#    'B078M7BTDL',
#    'B0017JKOBS',
#    'B011TR4ZFS',
#    'B00C1P9M60',
#    'B01MUBBAC8',
#    'B07H81D4MX',
#    'B00KXAUPSE',
#    'B07GRR71K6',
#    'B01DTO6UA2',
#    'B0742BL3R1',
#    'B074P7T3LS',
#    'B0784YSVTK',
#    'B07DW49Y9P',
#    'B074CTQWYS',
#    'B07F5QFC92',
#    'B07FN9LSKL',
#    '0679882812',
#    'B06XL1B7QN',
#    'B00A6TBITM',
#    'B075RDRJLX',
#    '1419727435',
#    'B074XNXTC6',
#    'B0748V7SNH',
#    'B0753QWL5X',
#    'B007R8XGJA',
#    'B015EB2868',
#    'B07DM5DC3Y',
#    'B00OXLY49A',
#    'B07CTBSB2Y']},
#  {'title': 'Converse Chuck Taylor All Star High Top',
#   'description': ['The iconic, timeless chuck taylor all star sneaker. Perfect in its simplicity since 1917. Lightweight, breathable canvas construction. Vulcanized rubber sole delivers durable traction. An ortholite insole cushions each and every step. AND no one can ignore the unmistakable ankle patch. Versatile, fashionable, and they keep looking better every time you wear them. Ortholite is a trademark of O2 partners, llc.'],
#   'brand': '',
#   'rank': '412 in Clothing, Shoes & Jewelry (',
#   'price': '$29.55 - $160.95',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Men',
#    'Shoes',
#    'Fashion Sneakers'],
#   'asin': 'B000089V5B',
#   'also_buy': ['B07HVFM4CG',
#    'B07C8V9T7T',
#    'B07B5FVT5K',
#    'B07CQB7P51',
#    'B074CTQWYS',
#    'B078KFTF9C',
#    'B0741XXSRZ',
#    'B0797K7NV7',
#    'B071CV9XJF',
#    'B06Y28W39C',
#    'B074V4DTPL',
#    'B01G2N1WKU',
#    'B0761XW9LR',
#    'B079Z7RJYZ',
#    'B078SMDX42',
#    'B01MFDPU86',
#    'B01MTLLV5O',
#    'B015R3OJJW',
#    'B0759ZPCV1',
#    'B06XG1PQ78',
#    'B01N5FVM36',
#    'B078MYB5XP',
#    'B07KTNZWF4',
#    'B077BFDKXM',
#    'B00605L38M',
#    'B00SUEEFOK',
#    'B0157G34AY',
#    'B00BXQIJ5S',
#    'B01M9C1PD1',
#    'B073XNXXDZ',
#    'B01GW2GH4M',
#    'B06Y4CJVQY']},
#  {'title': 'Donna Karan Hosiery The Nudes Essential Toner Pantyhose',
#   'description': ['Donna Karan Hosiery Style D55. Ultra-sheer pantyhose. Control top - shapes tummy, hips and upper thighs. Invisible reinforced toe.'],
#   'brand': 'Donna Karan Hosiery',
#   'rank': '113,116 in Clothing, Shoes & Jewelry (',
#   'price': '$20.00 - $22.00',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Women',
#    'Clothing',
#    'Socks & Hosiery',
#    'Sheers',
#    'nylon',
#    'Style D55'],
#   'asin': 'B00008AASS',
#   'also_buy': ['B000BD1LOA',
#    'B075HD5K2D',
#    'B07BGV389K',
#    'B06XYK7D2B',
#    'B00H4IKF0G',
#    'B07GCWQKPM',
#    'B075H9YPK6',
#    'B07C1Z15CS',
#    'B075K89QGN',
#    'B07BYW3P8J',
#    'B07CH45LYC',
#    'B07GZ1LC6P',
#    'B002PZVCVE',
#    'B005ZY14JW',
#    'B00L3YCRR6',
#    'B06XYLJKRN',
#    'B016TUDBEG',
#    'B01ETP2OL4',
#    'B003XRQQHI',
#    'B009SA1TS0',
#    'B000B2M2XK',
#    'B002Q00O3A',
#    'B00L3YCRN0',
#    'B07CKC2F6T',
#    'B01N5EZ6UN',
#    'B01JK759R2',
#    'B07482KY8C',
#    'B014V62CXQ',
#    'B01DMVBPPC',
#    'B0007OP0QS',
#    'B075DQ86FL',
#    'B002HRF888',
#    'B014E9N568',
#    'B009Q6ND0S',
#    'B07HGH1FSN',
#    'B0178EXLYC',
#    'B009YQ5Q3C',
#    'B07H9NQ9R4',
#    'B004DMYNBI',
#    'B07C9S626Y',
#    'B002Q00MIM',
#    '0865653518',
#    'B0002V32NE',
#    'B0002V31Z8',
#    'B00JL6K25W',
#    'B07D19WRQ8',
#    'B01GPLAJUI',
#    'B01JK759SG',
#    'B00L3YCRSK',
#    'B013LX35PY',
#    'B07G3R6LVW',
#    'B002Q00MQ4',
#    'B01C2S2A3M',
#    'B01M06Z792',
#    'B004DNWNEG',
#    'B004YJQ02K',
#    'B076H3DGWC',
#    'B0724ZL1PT',
#    'B0081UZ1ZK',
#    'B00IO7FJJS',
#    'B004FUV0EQ',
#    'B06Y3HTJ2Q',
#    'B01B6CXJ9O',
#    'B00WUW14A6',
#    'B01N0TOHFK',
#    'B0000BYCO5',
#    'B013WMWV36',
#    '0451209338',
#    'B00CFD4T52',
#    'B01LZRSEOJ',
#    'B002HJ644S',
#    'B00KK85N40',
#    'B001TJKEFC',
#    'B006MY41JO',
#    'B06XDQVJ28',
#    '0670026190',
#    '0399590501',
#    'B013JA30P4',
#    'B07FMXC63V',
#    '1455588741',
#    'B0178HMG1I',
#    'B01B6QGNYI']},
#  {'title': "Bali Women's Skimp Skamp Brief Panty Number 2633",
#   'description': ['This skimp skamp brief provides light, natural shaping and gives you full coverage in front and back',
#    "You have to try it on to believe how good it feels. Our Skimp Skamp Brief is the sleekest panty you've ever worn. A center back seam provides light, natural shaping and the Brief panty style gives you full coverage in front and back. No wonder it's a favorite at department stores."],
#   'brand': '',
#   'rank': '34,776 in Clothing, Shoes & Jewelry (',
#   'price': '$2.79 - $41.36',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Women',
#    'Clothing',
#    'Lingerie, Sleep & Lounge',
#    'Lingerie',
#    'Panties',
#    'Briefs'],
#   'asin': 'B00008I8YM',
#   'also_buy': ['B01N5T4GDA',
#    'B00NB17D0K',
#    'B072LDPM3P',
#    'B07G2RZ6Z5',
#    'B07C9RVPY4',
#    'B074W4WYNY',
#    'B008IDTLP6',
#    'B000MX97JA',
#    'B07C22VJLZ',
#    'B075J3T6MD',
#    'B012Y3X2DW',
#    'B012Y3I6IS',
#    'B077YDJX1B',
#    'B00889JGXM',
#    'B07DK35GST',
#    'B01CODR03A',
#    'B012Y3VNTM',
#    'B0019ZGVLC',
#    'B00WOJ4MJ0',
#    'B06XSDD7Q7',
#    'B0006TOO1G',
#    'B0012QM8IS',
#    'B012Y3ITVW',
#    'B01F96UKMM',
#    'B002DPUZ2S',
#    'B012Y3GHZW',
#    'B00E94IMAI',
#    'B000MX970E',
#    'B012Y3FJ3S',
#    'B075J4DKDR',
#    'B074YGQ9QF',
#    'B000MXB6NA',
#    'B012Y3JEAW',
#    'B07F6Z2X4R',
#    'B012Y3NUW0',
#    'B01MZCVIU5',
#    'B012Y3F3VQ',
#    'B079T9YZJ6',
#    'B07BMFLT54',
#    'B008IDTL8I',
#    'B012Y3WOP4',
#    'B000VJ48VC',
#    'B00QF6SHR6',
#    'B0742F5SCZ',
#    'B0711XWPVB',
#    'B07C7S3YCP',
#    'B074VM88NH',
#    'B003VROI7A',
#    'B0019ZGSRO',
#    'B071HP3ZSV',
#    'B07HFB226Z',
#    'B0776HFJTL',
#    'B0007UOLUI',
#    'B075XK8DR1',
#    'B01LX72URE',
#    'B07CP4K8BS',
#    'B004PEHJ6A',
#    'B07236WQXP',
#    'B07B43QNYQ',
#    'B01MZH773S',
#    'B07BC8ZFD9',
#    'B01ATUR76U',
#    'B012Y3YDW6',
#    'B07CPPX3H2',
#    'B00JIKL20A',
#    'B07BMS4MK7',
#    'B00JL6JVOK',
#    'B00E94IM9O',
#    'B000MX96M8',
#    'B01LW2PXIF',
#    'B00W50X4HO',
#    'B07D3Q6VV4',
#    'B00NBSPKDA',
#    'B01G5M8P0S',
#    'B01G5M8OW2',
#    'B00K0OWR5W',
#    'B071VP8TT3',
#    'B012Y3RQWU',
#    'B00KRZB2A0',
#    'B0007YY8H0',
#    'B07HYHMGLF',
#    'B004PEHJ6U',
#    'B01MR3G1PM',
#    'B019WZPM8S',
#    'B00LIYO8U0',
#    'B00JXU13MW',
#    'B07CZ7JRP4',
#    'B06X3WVL2H',
#    'B01LWIH9LK',
#    'B00NOU438I',
#    'B009YRM6MK']},
#  {'title': "Fantasie Women's Smoothing Moulded Full Cup Bra 4500",
#   'description': ['This seamless, molded bra provides full coverage for a more modest and smooth fit'],
#   'brand': 'Fantasie',
#   'rank': '675,984 in Clothing, Shoes & Jewelry (',
#   'price': '$24.00 - $50.00',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Women',
#    'Clothing',
#    'Lingerie, Sleep & Lounge',
#    'Lingerie',
#    'Bras',
#    'Everyday Bras'],
#   'asin': 'B00008IOI3',
#   'also_buy': ['B00UTGOD62',
#    'B0187AO1CC',
#    'B00UTGODQ2',
#    'B0187AO1JA',
#    'B00UTGOCSG',
#    'B0187ANYV6',
#    'B00QI9V97A',
#    'B079CZC4MW',
#    'B00008IO7V',
#    'B00DS4SIFE',
#    'B00UTGOG6O',
#    'B01H64LGQ4',
#    'B0010HSMR0',
#    'B01C9CACF4',
#    'B01DK53OOK',
#    'B005X5FG2O',
#    'B01MYMMW9B',
#    'B001ULCBG4',
#    'B004TPLVSC',
#    'B00KIL2AR2',
#    'B018KU29UA',
#    'B000074RL3',
#    'B01MXL3ZAF',
#    'B0054M74NU',
#    'B00DBSAE0Y',
#    'B01CQDK8MI',
#    'B0187AO1OU',
#    'B0054M6BRK',
#    'B01DD5SK32',
#    'B01DD5SJYM',
#    'B01N55DVWC',
#    'B0187ANYSY',
#    'B079J2VWLG',
#    'B0771SZMPM']},
#  {'title': 'Timex Anna Avenue Watch',
#   'description': [],
#   'brand': 'Timex',
#   'rank': '24,414 in Clothing, Shoes & Jewelry (',
#   'price': '$3.99',
#   'category': ['Clothing, Shoes & Jewelry', 'Women', 'Watches'],
#   'asin': 'B00008IM8Q',
#   'also_buy': ['B0007GHCT4',
#    'B01I9OOS2O',
#    'B00PUDNGLM',
#    'B06XBY6MY2',
#    'B01I9OSCGW',
#    'B01I9OP25Q',
#    'B01I9OJ9AK',
#    'B000AYTYJE',
#    'B01I9ON4D8',
#    'B07F7J9LHM',
#    'B07LDSQRR5',
#    'B07BMFGG5J',
#    'B00F2OC4C6',
#    'B00PUE3Z8U',
#    'B01I9OOD4W',
#    'B01I9ONEJM',
#    'B01CDV7REA',
#    '168412493X',
#    'B072JMJ7LJ',
#    'B01MSU05MY',
#    'B079GFG7SW',
#    'B074R5WW8S',
#    'B07BFQ5R71',
#    'B07DG3F8N2',
#    'B009OZKD1I',
#    'B009D80VSG',
#    'B002U6AALG',
#    'B00B6U0HH4',
#    'B07557T9FW',
#    '1501171682',
#    'B00551OTBK',
#    'B00QPHNUYU',
#    'B06WLNVHFX',
#    'B0719C5P56',
#    'B01LW2O9HP',
#    'B00GDHVQOI',
#    'B00BXLUH80',
#    'B00WJDWG3A',
#    'B000HJ7AIY']},
#  {'title': "Berkshire Women's Trend Fishnet Thigh High Pantyhose 1535",
#   'description': ["This fishnet thigh-hi has a non-bind stay up silicone top and is made from nylon/spandex to ensure they won't slip."],
#   'brand': '',
#   'rank': '831,502 in Clothing, Shoes & Jewelry (',
#   'price': '$8.82 - $9.95',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Women',
#    'Clothing',
#    'Socks & Hosiery',
#    'Sheers'],
#   'asin': 'B00008IPAC',
#   'also_buy': ['B00JL6JVQS',
#    'B00JL6JN6G',
#    'B00JL6JVVS',
#    'B00JL6K284',
#    'B00JL6JVOK',
#    'B01E7QKE5S',
#    'B000U63TPW',
#    'B000GIQJ42',
#    'B00EDF4GS0',
#    'B004DNWNF0',
#    'B009YQ5QGO',
#    'B01LWPZ078',
#    'B07894LPXG',
#    'B000GIQJ3S',
#    'B01N4NSJ3I',
#    'B074S4Y1RH',
#    'B00JL6JVNG',
#    'B01N0X4MJ2',
#    'B01IP5VYB0',
#    'B01JG874KA',
#    'B06XX6RVPS',
#    'B07CRNL1XH',
#    'B07BTZ5HV4',
#    'B01EZ8DG5I',
#    'B06Y25KWZK',
#    'B01LFOY1OU',
#    'B074BW3B16',
#    'B000GIP966',
#    'B000ZHFCPQ',
#    'B07BJBS4PB',
#    'B000X1GFKA',
#    'B06Y1RVV5W',
#    'B071CZ7F54',
#    'B01CE1NDMO',
#    'B0711411F6',
#    'B0146Q3HGM',
#    'B01HMFJNFI',
#    'B01M1DTHV0',
#    'B008WG8IQC',
#    'B07CR6KY4L',
#    'B06XHH1V5F',
#    'B000ZHFC2E',
#    'B00ZDVL91K',
#    'B00OIKLWBY',
#    'B01MRJP47R',
#    'B010T6TC3U',
#    'B00607AGJW',
#    'B000GIQZ9Q',
#    'B07C53VDQM',
#    'B0077IGF3E',
#    'B00WZYPQ7Q',
#    'B01A3IX7T4',
#    'B07BNVJDJ9']},
#  {'title': 'DKNY Opaque Tights 2-Pack',
#   'description': [],
#   'brand': '',
#   'rank': '48,965 in Clothing, Shoes & Jewelry (',
#   'price': '$18.48 - $25.00',
#   'category': ['Clothing, Shoes & Jewelry',
#    'Women',
#    'Clothing',
#    'Socks & Hosiery',
#    'Tights'],
#   'asin': 'B00008IPMW',
#   'also_buy': ['B01JK759R2',
#    'B01JK759SG',
#    'B01JK759TU',
#    'B009SA1TS0',
#    'B01JK759SQ',
#    'B004YJQ02K',
#    'B07GFR2ZXD',
#    'B075DQ86FL',
#    'B0002V31Z8',
#    'B06WVDXS75',
#    'B07B431HXP',
#    'B01N22S356',
#    'B00NOU42G6',
#    'B0754SNN61',
#    'B0002V32NE',
#    'B000BD1LOA',
#    'B00ZQACQ4C',
#    'B01M4KF04J',
#    'B0724ZL1PT',
#    'B00JL6JT7O',
#    'B06XX28LWG',
#    'B07GG679SX',
#    'B07BZH1C4R',
#    'B01MG5X6DH',
#    'B07GFWX12B',
#    'B00UPI56Q0',
#    'B00OOELIDG',
#    'B00L3YCRR6',
#    'B073RDRM2Y',
#    'B004DMYNBI',
#    'B07BL2M7ZN',
#    'B018A32IPS',
#    'B00KZD9CVA',
#    'B07C4Z6DY3',
#    'B00OOELIL8',
#    'B0054Y1YBQ',
#    'B014MDE4NO',
#    'B016X5TX4O',
#    'B01AJKCL9S',
#    'B0716ZTN4M',
#    'B07BSYV837',
#    'B00NOU3ZVE',
#    'B01GZDPMF8',
#    'B01MZIPUPC',
#    'B01IT58IMY',
#    'B07H9GQBZC',
#    'B0176VDUSE',
#    'B07C9H78QT',
#    'B004DNWNEG',
#    'B00HQ6K2KY',
#    'B000BQY6DU',
#    'B000I1X42M',
#    'B00DMDZF6Q',
#    'B000IELD9A',
#    'B07H3DNZQQ',
#    'B002YQ2GEG',
#    'B01GUBB3I0',
#    'B07BH21WWK',
#    'B01N3Q3UOG',
#    '0756698359',
#    'B00NMB04I2',
#    '0997895829',
#    'B009ZT52J6',
#    'B07BDKWX96',
#    'B01N5EZ6UN',
#    '1943451427',
#    '1422619435',
#    'B004DNWNDC',
#    'B01LZRSEOJ',
#    '1422620557',
#    'B004DNWN3C',
#    'B00W50X9PQ',
#    'B017LJYDO6',
#    'B01IUJG6X2',
#    'B001U88UN0',
#    'B07BZHG1KN',
#    'B07BJBS4PB',
#    'B00XAQDASU',
#    'B07BP3VN7X',
#    'B076H22874',
#    'B071D957M8',
#    '0307929566',
#    'B012W4F6QY',
#    'B07C4MB3R2',
#    'B01IHXX17K',
#    'B073TZCZQM',
#    'B01APP21VU']},
#  {'title': 'Hanes Women&rsquo;s Alive Full Support Control Top Pantyhose',
#   'description': [],
#   'brand': '',
#   'rank': '23,806 in Clothing, Shoes & Jewelry (',
#   'price': '$4.70 - $35.20',
#   'category': ['Clothing, Shoes & Jewelry', 'Women'],
#   'asin': 'B00008IQ74',
#   'also_buy': ['B00IJINORG',
#    'B004DNWNEG',
#    'B004DNWNDC',
#    'B06W553LMH',
#    'B009ZTFNZO',
#    'B00NOU42G6',
#    'B00F31JQK6',
#    'B011GP6APQ',
#    'B00DMDZF6Q',
#    'B011GP6FHY',
#    'B00LVNUH80',
#    'B010T6Q6LQ',
#    'B011GP6ADS',
#    'B0724ZL1PT',
#    'B06XHDNP14',
#    'B011GP6HFE',
#    'B00NHQHDHW',
#    'B00NOU4E6O',
#    'B00N4SYYO8',
#    'B00N4WWT1O',
#    'B076M3XCGS',
#    'B013GKG3D8',
#    'B00W50X4CE',
#    'B00F31J2L4',
#    'B00MA7027C',
#    'B073M6LM9T',
#    'B01N22S356',
#    'B004DNWMN8',
#    'B0002V31Z8',
#    'B004DNWNF0',
#    'B07FJW6Q12',
#    'B00VZA4OP6',
#    'B013LX35PY',
#    'B00LVNUH5I',
#    '0310764963',
#    'B001U88UJ4',
#    'B01N3Q3UOG',
#    'B001U88UF8',
#    'B01DVU5LCM',
#    'B01M2ZTM3F',
#    'B075DQ86FL',
#    'B07D5SWFKR',
#    'B07CVJC3YT',
#    'B004YJQ02K',
#    'B07622LLHC',
#    'B07BRLZ8KY',
#    'B0793GSKLT',
#    'B00T7HRG3G',
#    'B007XVL51C',
#    'B00EVONLUW',
#    'B00NBSPHAQ',
#    'B07MNR5M57',
#    'B004BD107O',
#    'B00JL6K4SM',
#    'B009YQ5Q3C',
#    'B07HMXHRDN',
#    'B00K7KREH0',
#    'B0748K749K',
#    'B00P6XH1X0',
#    '194035286X',
#    'B00QJBVUY4',
#    'B00IIFFEPU',
#    'B018IZSYEW',
#    'B07BL2M7ZN',
#    'B07HVX7S64',
#    'B01LXNLXYE',
#    'B07H8ZNXXJ',
#    'B00RSAF6NQ',
#    'B074TT4K2K',
#    'B00Q3KFX8U',
#    'B01AJKCL9S']},
#  ...]

# %% [markdown]
# ### Create Dataframe

# %%
# Creating a DataFrame
df = pd.DataFrame(preprocessed_data)
df
# Out:
#                                                      title  \
# 0        QIBOE Men's Baggy Jeans Denim Sweatpants Loose...
# 1                  Crazy Women's Voile Crinkle Scarf Shawl
# 2        FQQ Women Sexy Lingerie Lace Dress Sheer Babyd...
# 3        Crazy Women's Sexy Leather Backless Bodycon Cl...
# 4        FQQ Women's Sexy Lingerie Babydoll Dress Sleep...
# ...                                                    ...
# 2686213  AIRSOFTPEAK Military Belt Security Mission Fir...
# 2686214  Hot Sale High Quality Model Js Superior Metal ...
# 2686215  Hasika All-Weather Diversified 8 x 8 Instant S...
# 2686216  Aluminum Camping Tent Guyline Runner Rope Tigh...
# 2686217  Beileshi Mini Max Reflex Red Dot Sight Dual Br...
#
#                                                description        brand  \
# 0        [<b>pant size(Unit:inch)</b><br> W30(tag30) Wa...        QIBOE
# 1        [Feature <br> -Great quality winter scarf. <br...        Crazy
# 2        [Material : Core-spun fabric silk <br> feature...          FQQ
# 3        [Material : Core-spun fabric silk <br> feature...        Crazy
# 4        [Material : Core-spun fabric silk <br> feature...          FQQ
# ...                                                    ...          ...
# 2686213  [<b>Specifications:</b><br><br>Adjustable Leng...  AIRSOFTPEAK
# 2686214  [<b>Model--------line Capacity(LBS-YDS)-------...      Ballant
# 2686215                                                 []       Hasika
# 2686216  [, <b>Description:</b>, 100% Brand new and hig...      Generic
# 2686217  [Tubeless design with reflex lens (ruby lens c...     Beileshi
#
#                                              rank    price  \
# 0        1,506,383 in Clothing, Shoes & Jewelry (   $38.99
# 1          273,519 in Clothing, Shoes & Jewelry (    $0.50
# 2        3,266,227 in Clothing, Shoes & Jewelry (    $2.80
# 3          641,576 in Clothing, Shoes & Jewelry (    $8.50
# 4        1,761,440 in Clothing, Shoes & Jewelry (    $4.50
# ...                                           ...      ...
# 2686213            244,921 in Sports & Outdoors (    $9.98
# 2686214          1,136,500 in Sports & Outdoors (
# 2686215            416,498 in Sports & Outdoors (  $134.99
# 2686216            255,216 in Sports & Outdoors (    $4.99
# 2686217            103,045 in Sports & Outdoors (   $21.88
#
#                                                   category        asin  \
# 0        [Clothing, Shoes & Jewelry, Men, Clothing, Jea...  6342509379
# 1        [Clothing, Shoes & Jewelry, Women, Accessories...  6342502315
# 2        [Clothing, Shoes & Jewelry, Women, Clothing, L...  6342522545
# 3        [Clothing, Shoes & Jewelry, Women, Clothing, D...  6342522898
# 4        [Clothing, Shoes & Jewelry, Women, Clothing, L...  6342523002
# ...                                                    ...         ...
# 2686213  [Sports & Outdoors, Sports & Fitness, Hunting ...  B013QOPJ6G
# 2686214  [Sports & Outdoors, Sports & Fitness, Hunting ...  B013QPG7E8
# 2686215  [Sports & Outdoors, Outdoor Recreation, Campin...  B013QPIVY2
# 2686216  [Sports & Outdoors, Outdoor Recreation, Campin...  B013QQKMO8
# 2686217  [Sports & Outdoors, Sports & Fitness, Hunting ...  B013QQHYTO
#
#                                                   also_buy
# 0        [B077GQQKRV, B07CBJQTF6, B07H2Z6S9J, B06Y26PZ5...
# 1        [B018YRBB80, B07FD9HWPM, B017M55DI4, B07KX6PPW...
# 2                                             [B00VBVXVPI]
# 3        [B01AHZSZ9A, B01I809NCO, B07219C7LQ, B06ZZBQMT...
# 4        [B06XY5N95G, B01LY4VKTL, B01EKRMG8C, B004SLKRY...
# ...                                                    ...
# 2686213  [B01H6Z7X74, B0013AVGKY, B01DNBIX38, B01M0MDRF...
# 2686214                                       [B01DVWV16A]
# 2686215  [B004Z10D16, B00VTJKB1O, B07CMZY6JB, B004MMEHT...
# 2686216  [B00LLUDFMI, B071WPWPGP, B01IHRAXD6, B07BHZDLQ...
# 2686217  [B004941DUE, B01LWLLGG1, B00JQNCMJO, B01DBRH71...
#
# [2686218 rows x 8 columns]

# %%
# Remove duplicates from the original DataFrame
df.drop_duplicates(subset=['title', 'asin'], inplace=True)

# %% [markdown]
# ### Replace Empty Values With NaN

# %%
def replace_empty_with_nan(value):
    
    #if a value is an empty string replace with nan
    if isinstance(value, str) and value.strip() == "": 
        return np.nan
    
    #if a value is an empty list replace with nan
    elif isinstance(value, list) and not value:
        return np.nan
    else:
        return value
    
df = df.applymap(replace_empty_with_nan)
df.isnull().sum()
# Out:
# title            1233
# description    524203
# brand          169880
# rank            18488
# price          925269
# category       112001
# asin                0
# also_buy            0
# dtype: int64

# %%
# Drop rows with missing values
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# title          0
# description    0
# brand          0
# rank           0
# price          0
# category       0
# asin           0
# also_buy       0
# dtype: int64

# %%
df
# Out:
#                                                      title  \
# 0        QIBOE Men's Baggy Jeans Denim Sweatpants Loose...
# 1                  Crazy Women's Voile Crinkle Scarf Shawl
# 2        FQQ Women Sexy Lingerie Lace Dress Sheer Babyd...
# 3        Crazy Women's Sexy Leather Backless Bodycon Cl...
# 4        FQQ Women's Sexy Lingerie Babydoll Dress Sleep...
# ...                                                    ...
# 2686209  Pro Impact Pro Swivel - Multi-Direction Heavy ...
# 2686210  Pro Impact Rugby Kicking Tee - Heavy Duty Adju...
# 2686213  AIRSOFTPEAK Military Belt Security Mission Fir...
# 2686216  Aluminum Camping Tent Guyline Runner Rope Tigh...
# 2686217  Beileshi Mini Max Reflex Red Dot Sight Dual Br...
#
#                                                description        brand  \
# 0        [<b>pant size(Unit:inch)</b><br> W30(tag30) Wa...        QIBOE
# 1        [Feature <br> -Great quality winter scarf. <br...        Crazy
# 2        [Material : Core-spun fabric silk <br> feature...          FQQ
# 3        [Material : Core-spun fabric silk <br> feature...        Crazy
# 4        [Material : Core-spun fabric silk <br> feature...          FQQ
# ...                                                    ...          ...
# 2686209  [, In order to get your speed bag set up, you&...   Pro Impact
# 2686210  [, Whether you&rsquo;re <b>practicing</b> or <...   Pro Impact
# 2686213  [<b>Specifications:</b><br><br>Adjustable Leng...  AIRSOFTPEAK
# 2686216  [, <b>Description:</b>, 100% Brand new and hig...      Generic
# 2686217  [Tubeless design with reflex lens (ruby lens c...     Beileshi
#
#                                              rank   price  \
# 0        1,506,383 in Clothing, Shoes & Jewelry (  $38.99
# 1          273,519 in Clothing, Shoes & Jewelry (   $0.50
# 2        3,266,227 in Clothing, Shoes & Jewelry (   $2.80
# 3          641,576 in Clothing, Shoes & Jewelry (   $8.50
# 4        1,761,440 in Clothing, Shoes & Jewelry (   $4.50
# ...                                           ...     ...
# 2686209            109,374 in Sports & Outdoors (  $29.99
# 2686210             73,247 in Sports & Outdoors (   $9.99
# 2686213            244,921 in Sports & Outdoors (   $9.98
# 2686216            255,216 in Sports & Outdoors (   $4.99
# 2686217            103,045 in Sports & Outdoors (  $21.88
#
#                                                   category        asin  \
# 0        [Clothing, Shoes & Jewelry, Men, Clothing, Jea...  6342509379
# 1        [Clothing, Shoes & Jewelry, Women, Accessories...  6342502315
# 2        [Clothing, Shoes & Jewelry, Women, Clothing, L...  6342522545
# 3        [Clothing, Shoes & Jewelry, Women, Clothing, D...  6342522898
# 4        [Clothing, Shoes & Jewelry, Women, Clothing, L...  6342523002
# ...                                                    ...         ...
# 2686209  [Sports & Outdoors, Sports & Fitness, Other Sp...  B013QN02Y6
# 2686210  [Sports & Outdoors, Sports & Fitness, Team Spo...  B013QN0Y3K
# 2686213  [Sports & Outdoors, Sports & Fitness, Hunting ...  B013QOPJ6G
# 2686216  [Sports & Outdoors, Outdoor Recreation, Campin...  B013QQKMO8
# 2686217  [Sports & Outdoors, Sports & Fitness, Hunting ...  B013QQHYTO
#
#                                                   also_buy
# 0        [B077GQQKRV, B07CBJQTF6, B07H2Z6S9J, B06Y26PZ5...
# 1        [B018YRBB80, B07FD9HWPM, B017M55DI4, B07KX6PPW...
# 2                                             [B00VBVXVPI]
# 3        [B01AHZSZ9A, B01I809NCO, B07219C7LQ, B06ZZBQMT...
# 4        [B06XY5N95G, B01LY4VKTL, B01EKRMG8C, B004SLKRY...
# ...                                                    ...
# 2686209  [B002ZPX2QW, B004JPUTJY, B008R166C0, B002XP18R...
# 2686210  [B003NO7SPU, B074YF68P3, B01FG07PII, B0088R319...
# 2686213  [B01H6Z7X74, B0013AVGKY, B01DNBIX38, B01M0MDRF...
# 2686216  [B00LLUDFMI, B071WPWPGP, B01IHRAXD6, B07BHZDLQ...
# 2686217  [B004941DUE, B01LWLLGG1, B00JQNCMJO, B01DBRH71...
#
# [1342510 rows x 8 columns]

# %% [markdown]
# ## Process Data and Create Output

# %%
# Create a dictionary to store mappings of asin codes to product titles
asin_to_title = dict(zip(df['asin'], df['title']))

# Create a new column for updated 'also_buy' list
df['also_buy_product_names'] = ""

# Iterate over each row of the DataFrame
for index, row in df.iterrows():
    also_buy_list = row['also_buy']  # Get the list of codes from 'also_buy' column
    also_buy_product_names = []  # List to store updated values
    updated_also_buy = []
    also_buy_product_names.append(row['title'])  
    updated_also_buy.append(row['asin'])
    
    # Iterate over each code in the 'also_buy' list
    for code in also_buy_list:
        # Check if the code exists in the asin_to_title dictionary
        if code in asin_to_title:
            also_buy_product_names.append(asin_to_title[code])  
            updated_also_buy.append(code)
    
    # Update the 'updated_also_buy' column with the updated list
    df.at[index, 'also_buy_product_names'] = also_buy_product_names
    df.at[index, 'also_buy'] = updated_also_buy

# %%
df
# Out:
#                                                      title  \
# 0        QIBOE Men's Baggy Jeans Denim Sweatpants Loose...
# 1                  Crazy Women's Voile Crinkle Scarf Shawl
# 2        FQQ Women Sexy Lingerie Lace Dress Sheer Babyd...
# 3        Crazy Women's Sexy Leather Backless Bodycon Cl...
# 4        FQQ Women's Sexy Lingerie Babydoll Dress Sleep...
# ...                                                    ...
# 2686209  Pro Impact Pro Swivel - Multi-Direction Heavy ...
# 2686210  Pro Impact Rugby Kicking Tee - Heavy Duty Adju...
# 2686213  AIRSOFTPEAK Military Belt Security Mission Fir...
# 2686216  Aluminum Camping Tent Guyline Runner Rope Tigh...
# 2686217  Beileshi Mini Max Reflex Red Dot Sight Dual Br...
#
#                                                description        brand  \
# 0        [<b>pant size(Unit:inch)</b><br> W30(tag30) Wa...        QIBOE
# 1        [Feature <br> -Great quality winter scarf. <br...        Crazy
# 2        [Material : Core-spun fabric silk <br> feature...          FQQ
# 3        [Material : Core-spun fabric silk <br> feature...        Crazy
# 4        [Material : Core-spun fabric silk <br> feature...          FQQ
# ...                                                    ...          ...
# 2686209  [, In order to get your speed bag set up, you&...   Pro Impact
# 2686210  [, Whether you&rsquo;re <b>practicing</b> or <...   Pro Impact
# 2686213  [<b>Specifications:</b><br><br>Adjustable Leng...  AIRSOFTPEAK
# 2686216  [, <b>Description:</b>, 100% Brand new and hig...      Generic
# 2686217  [Tubeless design with reflex lens (ruby lens c...     Beileshi
#
#                                              rank   price  \
# 0        1,506,383 in Clothing, Shoes & Jewelry (  $38.99
# 1          273,519 in Clothing, Shoes & Jewelry (   $0.50
# 2        3,266,227 in Clothing, Shoes & Jewelry (   $2.80
# 3          641,576 in Clothing, Shoes & Jewelry (   $8.50
# 4        1,761,440 in Clothing, Shoes & Jewelry (   $4.50
# ...                                           ...     ...
# 2686209            109,374 in Sports & Outdoors (  $29.99
# 2686210             73,247 in Sports & Outdoors (   $9.99
# 2686213            244,921 in Sports & Outdoors (   $9.98
# 2686216            255,216 in Sports & Outdoors (   $4.99
# 2686217            103,045 in Sports & Outdoors (  $21.88
#
#                                                   category        asin  \
# 0        [Clothing, Shoes & Jewelry, Men, Clothing, Jea...  6342509379
# 1        [Clothing, Shoes & Jewelry, Women, Accessories...  6342502315
# 2        [Clothing, Shoes & Jewelry, Women, Clothing, L...  6342522545
# 3        [Clothing, Shoes & Jewelry, Women, Clothing, D...  6342522898
# 4        [Clothing, Shoes & Jewelry, Women, Clothing, L...  6342523002
# ...                                                    ...         ...
# 2686209  [Sports & Outdoors, Sports & Fitness, Other Sp...  B013QN02Y6
# 2686210  [Sports & Outdoors, Sports & Fitness, Team Spo...  B013QN0Y3K
# 2686213  [Sports & Outdoors, Sports & Fitness, Hunting ...  B013QOPJ6G
# 2686216  [Sports & Outdoors, Outdoor Recreation, Campin...  B013QQKMO8
# 2686217  [Sports & Outdoors, Sports & Fitness, Hunting ...  B013QQHYTO
#
#                                                   also_buy  \
# 0                                             [6342509379]
# 1         [6342502315, B00NSF70KM, B00KU1NLGO, B00G9EMVIA]
# 2                                             [6342522545]
# 3                                 [6342522898, B01H43Z5GY]
# 4                                             [6342523002]
# ...                                                    ...
# 2686209  [B013QN02Y6, B00LLXIMZU, B001B88VXI, B00175YK9...
# 2686210  [B013QN0Y3K, B000TE9ZFI, B00WMJR00U, B001MGQBA...
# 2686213  [B013QOPJ6G, B0013AVGKY, B00AOCFPPE, B005DT80S...
# 2686216   [B013QQKMO8, B013FOVIGC, B005188T90, B006ZC5KLG]
# 2686217  [B013QQHYTO, B004SKCUME, B001WJ6908, B00ELVDM0...
#
#                                     also_buy_product_names
# 0        [QIBOE Men's Baggy Jeans Denim Sweatpants Loos...
# 1        [Crazy Women's Voile Crinkle Scarf Shawl, Here...
# 2        [FQQ Women Sexy Lingerie Lace Dress Sheer Baby...
# 3        [Crazy Women's Sexy Leather Backless Bodycon C...
# 4        [FQQ Women's Sexy Lingerie Babydoll Dress Slee...
# ...                                                    ...
# 2686209  [Pro Impact Pro Swivel - Multi-Direction Heavy...
# 2686210  [Pro Impact Rugby Kicking Tee - Heavy Duty Adj...
# 2686213  [AIRSOFTPEAK Military Belt Security Mission Fi...
# 2686216  [Aluminum Camping Tent Guyline Runner Rope Tig...
# 2686217  [Beileshi Mini Max Reflex Red Dot Sight Dual B...
#
# [1342510 rows x 9 columns]

# %% [markdown]
# ## Output to JSON

# %%
# Open a JSON file in write mode
with open('output.json', 'w') as f:
    # Iterate over each row in the DataFrame
    for _, row in df.iterrows():
        # Convert the row to a JSON string and write it to the file with a newline character
        f.write(json.dumps(row.to_dict()) + '\n')
